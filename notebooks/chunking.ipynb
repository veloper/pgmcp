# %%
# Automatically reload modules when code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pgmcp.settings import get_settings

SETTINGS = get_settings()
from rich.table import Table
from rich.console import Console
console = Console()

# %%
from sqlalchemy.future import select
from pgmcp.models import CrawlJob

async with CrawlJob.async_context() as session:
    crawl_job = await CrawlJob.find(21)
    assert crawl_job is not None, "CrawlJob with ID 21 not found"
    await crawl_job.ensure_loaded("crawl_items")
    crawl_items = crawl_job.crawl_items  # This is now loaded and safe to access

# %%
crawl_item = crawl_items[5]
html = crawl_item.body

# %%
from pgmcp.chunking.document import Document

document = Document.from_html(html)

console.log(document.chunks())
# Out:
# [08:58:46] [                                                                                        ]8;id=412562;file:///var/folders/gp/nqwc90vj2yj011g2dyv2mjlm0000gn/T/ipykernel_59739/1961401648.py\1961401648.py]8;;\:]8;id=967648;file:///var/folders/gp/nqwc90vj2yj011g2dyv2mjlm0000gn/T/ipykernel_59739/1961401648.py#5\5]8;;\
#                Chunk(
#                    meta=ChunkMeta(
#                        root={
#                            'Header 1': 'ORM Quick Start¶',
#                            'part_id': 0,
#                            'title': 'ORM Quick Start'
#                        }
#                    ),
#                    content='For new users who want to quickly see what basic ORM use looks like,
#            here’s an\nabbreviated form of the mappings and examples used in the\nSQLAlchemy Unified
#            Tutorial. The code here is fully runnable from a clean command\nline.  \nAs the
# ...
